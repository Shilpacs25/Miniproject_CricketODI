# %% [markdown]
# # **Mini Project**
#
# ## Classification and Prediction of Cricket ODI Winning Teams

# %% [markdown]
# # PHASE-1
#
# ### 1.	Define Problem statement
#
#  The Cricket ODI dataset offers an opportunity for extensive exploratory data analysis (EDA), statistical analysis, and regression modeling. With details on participating teams, match winners, venues, innings, and runs scored, the project's primary goal is to uncover factors influencing match outcomes. Additionally, the project aims to employ regression modeling to predict which team, among two participants, will emerge as the winner. By discovering patterns and relationships, the analysis seeks to reveal key factors impacting match results and enhance the understanding of team performance dynamics.. Through EDA, statistical analysis,regression and classification modeling, the project aims to provide valuable insights into the world of ODI cricket.
#
#
#
# ### 2.	Create project plan and product backlog
#
# ### Project Plan:
#
# #### Project Objective: To conduct a comprehensive analysis of a cricket One Day International (ODI) dataset through data preprocessing, exploratory data analysis (EDA), statistical analysis, and regression,classification modeling. The primary focus is on gaining insights into player performance and accurately predicting match outcomes.
#
#
#
# #### 1. Data Collection and Preprocessing :
# * Collect ODI dataset from reliable sources (e.g., ICC, ESPN, or Kaggle).
#
# * Perform data preprocessing:.
#            -  Handle missing values.
#            -  Address data types and outliers.
#            -  Feature engineering if necessary.
#
#
# #### 2. Exploratory Data Analysis (EDA) :
# * Generate summary statistics .
# * Create visualizations (bar charts, histograms, scatter plots) to represent key insights.
# * Identify trends and correlations within the dataset.
#
#
# #### 3. Statistical Analysis :
# * Conduct hypothesis testing to answer specific questions.
# * Analyse batting averages, bowling averages, centuries, and other relevant cricket statistics.
# * Perform t-tests, ANOVA, or other statistical tests to support hypotheses.
#
#
# #### 4. Probability Distribution Analysis :
# * Analyse probability distributions for cricket metrics, including runs scored, and match results.
# * Calculate probabilities, expected values, and confidence intervals.
# * Visualize probability distributions (histograms, density plots).
#
#
# #### 5. EDA and Statistical Analysis :
# * EDA and statistical analysis on the dataset.
# * Include visuals, tables, and interpretations.
# * Discuss key insights and trends.
#
#
# #### 6. Probability Distribution Analysis Report
# * Probability distribution analysis .
# * Present findings and insights from the analysis.
#
#
# #### 7. Regression Modeling Report:
# * Provide a detailed report on the regression modeling process.
# * Include the implementation of various regression algorithms and their outcomes.
# * Discuss the accuracy and performance of each model.
#
#
# #### 8.Classification Modeling :
#
# * Implement classification models (logistic regression, decision tree classifier, etc.).
# * Evaluate classification accuracy, precision, recall, and F1 score.
# * Generate classification reports and confusion matrices.
#
#
# ### Product Backlog:
#
#
# #### 1.To implement the following statistical tests on the Cricket ODI dataset:
# * Dispersion for the parameters
# * Data distribution
# * Test statistic
# * Test type (T-test, Z-test, F-test, ANOVA, Chi-Square, PCA)
#
#
# ####  2.To implement the following data visualization techniques on the Cricket ODI dataset:
# * Distribution
# * Histogram
# * Scatter plots
# * Bar plot
# * Box plot
# * FacetGrid
# * Heatmap
# * Crosstab
# * Line plot
#
#
# ####  3.To conduct the following exploratory data analysis on the Cricket ODI dataset:
# * Univariate analysis
# * Bivariate analysis
# * Multivariate analysis
#
#
# ####  4.Regression Modeling:
# * Implement a variety of regression models to predict match outcomes and player performance.
# * linear regression, decision tree regression ,logistic regression ,support vector regressor and random forest regression.
# * Evaluate model accuracy using appropriate metrics (e.g., Mean Squared Error, R-squared).
# * Conduct feature selection and engineering for optimal regression model performance.
#
#
# ####  5.Evaluation Metrics:
# * Implement evaluation metrics for statistical tests and regression models.
# * Assess the effectiveness of statistical tests and visualization techniques.
# * Evaluate the accuracy and performance of regression models using relevant metrics.
#
#
# #### 6.Classification Modeling:
# * Implement a variety of classification models to predict match outcomes and player performance.
#  - Logistic Regression
#  - Decision Tree Classifier
#  - Random Forest Classifier
#  - Support Vector Classifier
#  - k-Nearest Neighbors (k-NN)
#
#
# ### 3.	Creation of Git Repository
# https://github.com/Shilpacs25/119CS21048-Mini-Project-

# %% [markdown]
# # Phase2

# %% [markdown]
# **Phase-2 (Summary)**
#
# **Statistical Analysis**
#
# **Data Exploration and analysis for the stated problem & Given Dataset (Coding)**
# 1.    Frame 10 questions on Probability & Statistics
# 2.    Dispersion for the parameters
# 3.    Data distribution
# 4.    Visualize above with Distribution, Histogram & Scatter Plots
# 5.    Test statistic
# 6.    Test type (T-test, Z-test, F-test, ANNOVA, Chi-Square, PCA)
# 7.    Interpreting test statistics

# %%
import pandas as pd

# %%
from scipy import stats
import seaborn as sns 

df = pd.read_csv('ContinousDataset.csv')

# %%
df.shape
# Out:
# (7494, 16)

# %%
df =df.drop('Unnamed: 0', axis=1)

# %%
df.describe()
# Out:
#         Team1_runs   Team2_runs   Total_runs
# count  7494.000000  7494.000000  7494.000000
# mean    225.711369   225.958233   450.912597
# std      46.373570    46.331239    61.237084
# min     150.000000   150.000000   303.000000
# 25%     187.000000   188.000000   408.000000
# 50%     225.000000   226.000000   451.000000
# 75%     263.000000   263.000000   494.000000
# max    1000.000000  1000.000000   800.000000

# %% [markdown]
# ## Statistical Analysis
# ## Data Exploration and analysis for the stated problem & Given Dataset.

# %% [markdown]
# ## A. Frame 10 questions on Probability & Statistics

# %% [markdown]
# 1. Calculate the mean of the Total runs
# 2. Calculate the standard deviation of the Total runs
# 3. Calculate the percentage of matches won by the home team
# 4. What is the average total runs scored in the dataset?
# 5. Is there a correlation between the Margin and the Total Runs scored in the matches?
# 6. What is the highest number of runs scored by a team?
# 7. What is the average number of runs scored by Team 1 in their first innings across all seasons?
# 8. Is the total runs scored by Team 1 normally distributed?
# 9. Calculate the probability of Team 1 scoring less than 250 runs in a match.
# 10. Calculate the Probability of Team 2 scoring more than 300 runs
# 11. What is the probability of India winning a match?
# 12. What is the probability of a match being won by the home team?

# %% [markdown]
# # 1.Calculate the mean of the Total runs

# %%
mean_winning_margin = df['Total_runs'].mean()
print("The mean of the Total runs : ",mean_winning_margin)
# Out:
# The mean of the Total runs :  450.91259674406194

# %% [markdown]
# # 2.Calculate the standard deviation of the Total runs

# %%
standard_deviation = df['Total_runs'].std()
print("The standard deviation of the Total runs : ",standard_deviation)
# Out:
# The standard deviation of the Total runs :  61.23708420474303

# %% [markdown]
# # 3. Calculate the percentage of matches won by the home team

# %%
home_team_wins = df[df["Host_Country"] == df["Winner"]].shape[0]
percentage_home_team_wins = home_team_wins / df.shape[0] * 100
percentage_home_team_wins
# Out:
# 40.40565785962103

# %% [markdown]
# # 4.What is the average total runs scored in the dataset?

# %%
average_total_runs = df['Total_runs'].mean()
print("Average total runs scored in the dataset:", average_total_runs)
# Out:
# Average total runs scored in the dataset: 450.91259674406194

# %% [markdown]
# # 5.Is there a correlation between the Margin and the Total Runs scored in the matches?

# %%
correlation = df['Team1_runs'].corr(df['Total_runs'])
print("Correlation between Margin and Total Runs scored:", correlation)
# Out:
# Correlation between Margin and Total Runs scored: 0.6628505159694387

# %% [markdown]
# # 6. What is the highest number of runs scored by a team?

# %%
highest_runs = max(df['Team1_runs'].max(), df['Team2_runs'].max())
print("The highest number of runs scored by a teams : ",highest_runs)
# Out:
# The highest number of runs scored by a teams :  1000

# %% [markdown]
# # 7.What is the average number of runs scored by Team 1 in their first innings across all seasons?

# %%
team1_first_innings_avg = df[df['Innings_Team1'] == 'First']['Team1_runs'].mean()
print("The average number of runs scored by Team 1 in their first innings across all seasons",team1_first_innings_avg)
# Out:
# The average number of runs scored by Team 1 in their first innings across all seasons 226.0250867360555

# %% [markdown]
# # 8.Is the total runs scored by Team 1 normally distributed?

# %%
result = stats.normaltest(df['Team1_runs'])
if result.pvalue < 0.05:
    print("Team 1 Runs are not normally distributed.")
else:
    print("Team 1 Runs are normally distributed.")
# Out:
# Team 1 Runs are not normally distributed.

# %% [markdown]
# # 9.Calculate the probability of Team 1 scoring less than 250 runs in a match.

# %%
probability = (df['Team1_runs'] < 250).mean()
print("Probability of Team 1 scoring less than 250 runs:", probability)
# Out:
# Probability of Team 1 scoring less than 250 runs: 0.6595943421403789

# %% [markdown]
# # 10. Calculate the Probability of Team 2 scoring more than 300 runs

# %%
probability = (df['Team2_runs'] > 300).mean()
print("Probability of Team 2 scoring more than 300 runs:", probability)
# Out:
# Probability of Team 2 scoring more than 300 runs: 0.0008006405124099279

# %% [markdown]
# # 11. What is the probability of India winning a match?

# %%
p_india_win = len(df[df['Winner'] == 'India']) / len(df)
print("The probability of India winning a match",p_india_win)
# Out:
# The probability of India winning a match 0.12676808113157192

# %% [markdown]
# # 12. What is the probability of a match being won by the home team?

# %%
p_home_team_win = len(df[df['Winner'] == df['Team 1']]) / len(df)
print("The probability of a match being won by the home team",p_home_team_win)
# Out:
# The probability of a match being won by the home team 0.5

# %% [markdown]
# ## B.Dispersion for the parameters
#
# * Standard Deviation
# * Variance
# * Range
# * Interquartile Range

# %% [markdown]
# ## Standard Deviation

# %% [markdown]
# ### Standard deviation for Team1_runs

# %%
std_deviation_team1 = df['Team1_runs'].std()
print("Standard Deviation for Team1_runs:", std_deviation_team1)
# Out:
# Standard Deviation for Team1_runs: 46.37357041474402

# %% [markdown]
# ### Standard deviation for Team2_runs

# %%
std_deviation_team2 = df['Team2_runs'].std()
print("Standard Deviation for Team2_runs:", std_deviation_team2)
# Out:
# Standard Deviation for Team2_runs: 46.33123930014373

# %% [markdown]
# ### Standard deviation for Total_runs

# %%
std_deviation_total = df['Total_runs'].std()
print("Standard Deviation for Total_runs:", std_deviation_total)
# Out:
# Standard Deviation for Total_runs: 61.23708420474303

# %% [markdown]
# # Variance

# %% [markdown]
# ### Variance of Team1_runs

# %%
variance_team1 = df['Team1_runs'].var()
print("Variance for Team1_runs:", variance_team1)
# Out:
# Variance for Team1_runs: 2150.508033011222

# %% [markdown]
# ### Variance of Team2_runs

# %%
variance_team2 = df['Team2_runs'].var()
print("Variance for Team2_runs:", variance_team2)
# Out:
# Variance for Team2_runs: 2146.583735087183

# %% [markdown]
# ### Variance for Total_runs

# %%
variance_total = df['Total_runs'].var()
print("Variance for Total_runs:", variance_total)
# Out:
# Variance for Total_runs: 3749.980481898788

# %% [markdown]
# # IQR

# %%
# IQR(Interquartile Range)
Q1 = df['Team1_runs'].quantile(0.25)
Q3 = df['Team1_runs'].quantile(0.75)
IQR = Q3 - Q1
print("Interquartile Range (IQR) of Team1 Runs:", IQR)
# Out:
# Interquartile Range (IQR) of Team1 Runs: 76.0

# %%
# IQR(Interquartile Range)
Q1 = df['Team2_runs'].quantile(0.25)
Q3 = df['Team2_runs'].quantile(0.75)
IQR = Q3 - Q1
print("Interquartile Range (IQR) of Team2 Runs:", IQR)
# Out:
# Interquartile Range (IQR) of Team2 Runs: 75.0

# %%
# IQR(Interquartile Range)
Q1 = df['Total_runs'].quantile(0.25)
Q3 = df['Total_runs'].quantile(0.75)
IQR = Q3 - Q1
print("Interquartile Range (IQR) of Total Runs:", IQR)
# Out:
# Interquartile Range (IQR) of Total Runs: 86.0

# %% [markdown]
# # Range

# %%
#the Range
data_min = df['Total_runs'].min()
data_max = df['Total_runs'].max()
data_range = data_max - data_min
print("Range of Total Runs:", data_range)
# Out:
# Range of Total Runs: 497

# %%
#the Range
data_min = df['Team1_runs'].min()
data_max = df['Team1_runs'].max()
data_range = data_max - data_min
print("Range of Team1 Runs:", data_range)
# Out:
# Range of Team1 Runs: 850

# %%
#the Range
data_min = df['Team2_runs'].min()
data_max = df['Team2_runs'].max()
data_range = data_max - data_min
print("Range of Team2 Runs:", data_range)
# Out:
# Range of Team2 Runs: 850

# %% [markdown]
# ## C.Data Distribution
# ### Visualize above with Distribution, Histogram & Scatter Plots

# %%
#Removing outliers 
#find iqr
q1=df['Team1_runs'].quantile(0.25)
q3=df['Team1_runs'].quantile(0.75)
print("Q1=",q1)
print("Q3=",q3)
iqr=q3-q1
print("iqr=",(q3-q1))
# calculate upperlimit and lowerlimit
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print("Lower limits= ",lower)
print("upper limits= ",upper)
df[df['Team1_runs'] > upper]
df[df['Team1_runs'] < lower]
df=df[df['Team1_runs'] < upper]
df['Team1_runs'].describe()
# Out:
# Q1= 187.0
# Q3= 263.0
# iqr= 76.0
# Lower limits=  73.0
# upper limits=  377.0
# count    7489.000000
# mean      225.307918
# std        43.545330
# min       150.000000
# 25%       187.000000
# 50%       225.000000
# 75%       263.000000
# max       300.000000
# Name: Team1_runs, dtype: float64

# %%
#Removing outliers 
#find iqr
q1=df['Team2_runs'].quantile(0.25)
q3=df['Team2_runs'].quantile(0.75)
print("Q1=",q1)
print("Q3=",q3)
iqr=q3-q1
print("iqr=",(q3-q1))
# calculate upperlimit and lowerlimit
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print("Lower limits= ",lower)
print("upper limits= ",upper)
df[df['Team2_runs'] > upper]
df[df['Team2_runs'] < lower]
df=df[df['Team2_runs'] < upper]
df['Team2_runs'].describe()
# Out:
# Q1= 188.0
# Q3= 263.0
# iqr= 75.0
# Lower limits=  75.5
# upper limits=  375.5
# count    7484.000000
# mean      225.521913
# std        43.058816
# min       150.000000
# 25%       188.000000
# 50%       226.000000
# 75%       263.000000
# max       350.000000
# Name: Team2_runs, dtype: float64

# %%
#Removing outliers 
#find iqr
q1=df['Total_runs'].quantile(0.25)
q3=df['Total_runs'].quantile(0.75)
print("Q1=",q1)
print("Q3=",q3)
iqr=q3-q1
print("iqr=",(q3-q1))
# calculate upperlimit and lowerlimit
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print("Lower limits= ",lower)
print("upper limits= ",upper)
df[df['Total_runs'] > upper]
df[df['Total_runs'] < lower]
df=df[df['Total_runs'] < upper]
df['Total_runs'].describe()
# Out:
# Q1= 408.0
# Q3= 494.0
# iqr= 86.0
# Lower limits=  279.0
# upper limits=  623.0
# count    7482.000000
# mean      450.827052
# std        61.043909
# min       303.000000
# 25%       408.000000
# 50%       451.000000
# 75%       494.000000
# max       600.000000
# Name: Total_runs, dtype: float64

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(10, 5))
sns.histplot(df['Total_runs'], bins=20, kde=True)
plt.title('Histogram of Total Runs')
plt.xlabel('Total Runs')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Team1_runs'], bins=20, kde=True)
plt.title('Histogram of Total Runs')
plt.xlabel('Total Runs')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Team2_runs'], bins=20, kde=True)
plt.title('Histogram of Total Runs')
plt.xlabel('Total Runs')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.scatter(df['Team1_runs'], df['Winner'])
plt.title('Scatter Plot of Total Runs')
plt.xlabel('Index')
plt.ylabel('Total Runs')
# Out:
# Text(0, 0.5, 'Total Runs')

# %%
plt.scatter(df.index,df['Innings_Team1'])
plt.title('Scatter Plot of Total Runs')
plt.xlabel('Innings_Team1')
plt.ylabel('Winner country')
plt.show()

# %%
plt.scatter(df.index,df['Innings_Team2'])
plt.title('Scatter Plot of Total Runs')
plt.xlabel('Innings_Team1')
plt.ylabel('Winner country')
plt.show()

# %% [markdown]
# ## D.Test statistic
# ### Test type (T-test, Z-test, F-test, ANNOVA, Chi-Square, PCA)

# %% [markdown]
# ## Chi-Square

# %% [markdown]
# ### 1. Does the choice of Ground significantly impact the probability of Team 1 winning?

# %%
contingency_table = pd.crosstab(df['Ground'], df['Winner'])

chi2, p, _, _ = stats.chi2_contingency(contingency_table)

#The null hypothesis is that the choice of 
#ground has no impact on the probability of Team 1 winning. 

#significance level (alpha)
alpha = 0.05
print("Chi-square:",chi2)
print(f"P-value for chi-square test: {p}")
# Checking if the p-value is less than alpha
if p < alpha:
    print("There is a significant association between Ground and Team 1 winning.")
else:
    print("Ground choice does not significantly impact the probability of Team 1 winning.")
# Out:
# Chi-square: 33029.37112931123
# P-value for chi-square test: 0.0
# There is a significant association between Ground and Team 1 winning.

# %% [markdown]
# # 2. Is there a correlation between the Winner and the Ground?

# %%
from sklearn.preprocessing import LabelEncoder 

label_encoder = LabelEncoder()
df['Winner_encoded'] = label_encoder.fit_transform(df['Winner'])
df['Ground_encoded'] = label_encoder.fit_transform(df['Ground'])

# contingency table
contingency_table = pd.crosstab(df['Winner_encoded'], df['Ground_encoded'])

# chi-square test
chi2, p, _, _ = stats.chi2_contingency(contingency_table)

# significance level (alpha)
alpha = 0.05
print("Chi-square:",chi2)
print(f"P-value for chi-square test: {p}")
# Check if the p-value is less than alpha
if p < alpha:
    print("There is a significant correlation between Winner and Ground.")
else:
    print("There is no significant correlation between Winner and Ground.")
# Out:
# Chi-square: 33029.37112931122
# P-value for chi-square test: 0.0
# There is a significant correlation between Winner and Ground.

# %% [markdown]
# ### Since the p-value is less than alpha, we reject the null hypothesis and conclude that there is a significant correlation between the Winner and Ground columns.

# %% [markdown]
# ## ANOVA

# %% [markdown]
# # 3.Can we conclude that the Home or Away status of the teams affects the match results?

# %%
# ANOVA test
f_stat, p_value = stats.f_oneway(df[df['Host_Country'] == 'Home']['Winner'], df[df['Host_Country'] == 'Away']['Winner'])

#significance level (alpha)
alpha = 0.05

# Checking if the p-value is less than alpha
print("Chi-square:",f_stat)
print(f"P-value for chi-square test: {p_value}")
if p_value < alpha:
    print("We can conclude that the Home or Away status of the teams significantly affects the match results.")
else:
    print("We cannot conclude that the Home or Away status of the teams significantly affects the match results.")
# Out:
# Chi-square: nan
# P-value for chi-square test: nan
# We cannot conclude that the Home or Away status of the teams significantly affects the match results.
# C:\Users\SHILPA G\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:3861: DegenerateDataWarning: at least one input has length 0
#   warnings.warn(stats.DegenerateDataWarning('at least one input '

# %% [markdown]
# ### This suggests that the home/away factor does affect the outcomes of matches.

# %% [markdown]
# ## F-test

# %% [markdown]
# # 4. Does the Winner's identity depend on whether they played at Home or  Away?

# %%
# ANOVA F-test
f_stat, p_value = stats.f_oneway(df[df['Host_Country'] == 'Home']['Winner'], df[df['Host_Country'] == 'Away']['Winner'])

# Set a significance level (alpha)
alpha = 0.05

print("Chi-square:",chi2)
print(f"P-value for chi-square test: {p}")

# Checking if the p-value is less than alpha
if p_value < alpha:
    print("The Winner's identity depends on whether they played at Home or Away.")
else:
    print("The Winner's identity does not significantly depend on whether they played at Home or Away.")
# Out:
# Chi-square: 33029.37112931122
# P-value for chi-square test: 0.0
# The Winner's identity does not significantly depend on whether they played at Home or Away.

# %% [markdown]
# ### The p-value is greater than alpha,The Winner's identity does not significantly depend on whether they played at Home or Away.

# %% [markdown]
# ## T-test

# %% [markdown]
# # 5. Do teams that bat first (Innings_Team1) tend to score more runs on average compared to teams that bat second?

# %%
df['Margin'] = pd.to_numeric(df['Margin'], errors='coerce')

team1_scores = df[df['Innings_Team1'] == 'First']['Margin']
team2_scores = df[df['Innings_Team2'] == 'First']['Margin']


team1_scores = team1_scores.dropna()
team2_scores = team2_scores.dropna()

#two-sample t-test
t_stat, p_value = stats.ttest_ind(team1_scores, team2_scores, equal_var=False)

alpha = 0.05
print("Chi-square:",t_stat)
print(f"P-value for chi-square test: {p_value}")
# Check if the p-value is less than alpha
if p_value < alpha:
    print("Teams batting first tend to score significantly more runs on average.")
else:
    print("There is no significant difference in the average scores between teams batting first and second.")
# Out:
# Chi-square: nan
# P-value for chi-square test: nan
# There is no significant difference in the average scores between teams batting first and second.

# %% [markdown]
# ### The hypothesis test conducted did not find a significant difference in the average scores of teams based on whether they batted first or second.

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
import numpy as np
n=['Team1_runs','Team2_runs','Total_runs']
data_stats=df[n]
pca = PCA(n_components=0.9) 
principal_components = pca.fit_transform(data_stats)
num_components = pca.n_components_
num_components
# Out:
# 2

# %% [markdown]
# ### The first two principal components explain 90% of the variance in the data.

# %% [markdown]
# # Phase-3

# %% [markdown]
# ## Exploratory Data Analysis
# ### Data Exploration and analysis for the stated problem & Given Dataset

# %% [markdown]
# ## 1. Univariate Analysis

# %% [markdown]
# # Bar Plot:
# * Visualize the number of matches won by each team.

# %%
team_wins = df['Winner'].value_counts()

plt.figure(figsize=(12, 6))
team_wins.plot(kind='bar', color='skyblue')
plt.title('Matches Won by Each Team')
plt.xlabel('Team')
plt.ylabel('Number of Wins')
plt.xticks(rotation=45)
plt.show()

# %%
winning_team = df['Winner'].value_counts().index[:10]
win_count = df['Winner'].value_counts().values[:10]

plt.figure(figsize=(12,8))
ax = sns.barplot(y = winning_team , x = win_count, orient='h', palette='winter')
plt.xlabel(xlabel='Team Names')
plt.ylabel(ylabel='Wins')
plt.title("Top 10 Teams by Wins", fontdict = {'size' : 'xx-large', 'fontweight' : 'bold'})
plt.show()

# %% [markdown]
# ### Insight 1 : Australia has won most numbers of matches

# %%
df['Year'] = df['Match Date'].str[-4:]

yeared=df.groupby("Year").size()
yeared.plot(kind="line",color="green",linewidth=4)
plt.title("ODI Cricket Matches by Year")
plt.ylabel("Number of Matches")
plt.show()

# %% [markdown]
# ### Insight 2 : The number of ODI matches played has increased over time.

# %%
sns.histplot(x=df['Host_Country'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Insight 3: Most of the matches were hosted by Australia

# %%
# KDE plot for the 'Team1_runs' column
plt.figure(figsize=(10, 6))
sns.kdeplot(df['Team1_runs'], fill=True)
plt.title('KDE Plot for Team 1 Runs')
plt.xlabel('Runs')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ### Insight 4: Team 1 typically scores around 250 runs per match.

# %% [markdown]
# ## 2.Bivariate analysis

# %%
plt.figure(figsize=(8, 6))
plt.boxplot([df['Team1_runs'], df['Team2_runs']], labels=['Team 1 Runs', 'Team 2 Runs'])
plt.title('Box Plot of Team 1 and Team 2 Runs')
plt.ylabel('Runs')
plt.show()

# %%
cross_tab = pd.crosstab(df['Team 1'], df['Winner'])
plt.figure(figsize=(12, 6))
sns.heatmap(cross_tab, annot=True, fmt="d", cmap="YlGnBu")
plt.title('Bivariate Analysis: Team 1 vs. Winner')
plt.xlabel('Winner')
plt.ylabel('Team 1')
plt.show()

# %% [markdown]
# ### Insight 1 : There is a positive correlation between the number of matches played and the number of matches won.

# %%
# Grouping the data by 'Ground' and count the number of wins for each ground
ground_wins = df[df['Winner'] == df['Team 1']]['Ground'].value_counts().reset_index()
ground_wins.columns = ['Ground', 'Wins']

# Sorting the data to get the top 10 grounds with the most wins
top_10_grounds = ground_wins.head(10)

# bar chart to visualize the top 10 grounds
plt.figure(figsize=(12, 6))
sns.barplot(x='Wins', y='Ground',data=top_10_grounds, palette='Set1')
plt.title('Top 10 Grounds with Most Wins')
plt.xlabel('Number of Wins')
plt.ylabel('Ground')
plt.show()

# %% [markdown]
# ### Insight 2 :Sharjah has the most wins, followed by Colombo and Dhaka 1.The least number of wins is in Brisbane

# %%
home_country_wins = df[df['Host_Country'] == df['Winner']]

#countplot to visualize the number of wins by each country in their home country
plt.figure(figsize=(12, 6))
sns.countplot(x='Winner', data=home_country_wins, palette='Set1')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title('Wins by Country in Their Home Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Insight 3 : Australia, England, and New Zealand have the highest number of wins in their home country, while Hong Kong and U.A.E. have the lowest number of wins in their home country

# %%
def determine_winning_team(row):
    if row['Winner'] == row['Team 1']:
        return 0  
    else:
        return 1  

# Apply the function to create the 'WinningTeam' column
df['WinningTeam'] = df.apply(determine_winning_team, axis=1)

# Display the resulting DataFrame
df
# Out:
#        Scorecard       Team 1       Team 2  Margin        Ground  \
# 0        ODI # 1    Australia      England     NaN     Melbourne
# 1        ODI # 2      England    Australia     NaN    Manchester
# 2        ODI # 3      England    Australia     NaN        Lord's
# 3        ODI # 4      England    Australia     NaN    Birmingham
# 4        ODI # 5  New Zealand     Pakistan     NaN  Christchurch
# ...          ...          ...          ...     ...           ...
# 7489  ODI # 3931  New Zealand        India     NaN          Pune
# 7490  ODI # 3932  New Zealand        India     NaN        Kanpur
# 7491  ODI # 3933      Namibia    Hong Kong     NaN        Mumbai
# 7492  ODI # 3934       U.S.A.      Bermuda     NaN        Mumbai
# 7493  ODI # 3935      Namibia  East Africa     NaN        Mumbai
#
#         Match Date       Winner Host_Country Venue_Team1 Venue_Team2  \
# 0      Jan 5, 1971    Australia    Australia        Home        Away
# ...

# %%
# Violin plot
plt.figure(figsize=(12, 8))
sns.violinplot(x='WinningTeam',y='Total_runs', data=df)
plt.title('Violin Plot of Total Runs by Winning Team')
plt.xlabel('Winning Team')
plt.ylabel('Total Runs')
plt.show()

# %% [markdown]
# ## 3. Multivariate analysis

# %%
colors=["gold","green","lightsteelblue","firebrick","royalblue"]
country = df['Host_Country'].value_counts().head().index
mat_count = df['Host_Country'].value_counts().head().values

plt.figure(figsize=(10, 8))
plt.title("Top 5 Countries by Matches Hosted", fontdict = {'size' : 'xx-large', 'fontweight' : 'bold'})
plt.pie(mat_count, labels=country, autopct='%0.2f%%',
        colors = colors, startangle=60, explode = [0.06,0.02,0.02,0.02,0.02], 
        textprops={'color':"black", 'size' : 'x-large', 'fontweight' : 'bold'})
plt.show()

# %% [markdown]
# ### Insight 1 : Australia has hosted the most matches, followed by India and England. New Zealand and South Africa have hosted the least matches 1

# %%
team_winner_counts = df.groupby(['Team 1', 'Winner']).size().unstack(fill_value=0)

# bar plot to visualize the number of matches won by each team
plt.figure(figsize=(12, 6))
team_winner_counts.plot(kind='bar', stacked=True, colormap='Set3', ax=plt.gca())
plt.title('Matches Won by Each Team')
plt.xlabel('Team')
plt.ylabel('Number of Wins')
plt.xticks(rotation=45)
plt.legend(title='Winner', loc='upper right', bbox_to_anchor=(1.2, 1))
plt.show()

# %% [markdown]
# ### Insight 2 : The highest number of matches won is by India followed by Australia and England. The lowest number of matches won is by Bermuda

# %%
corr_matrix = df.corr()

# heatmap to visualize the correlation
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\SHILPA G\AppData\Local\Temp\ipykernel_7900\857155355.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %% [markdown]
# ### Insight 3 :Team1_runs and Total_runs are positively correlated, Innings Team1
# ### and Innings Team2 are negatively correlated, Winner and Team1_runs are
# ### positively correlated,Winner and Team2_runs are also positively correlated.

# %%
team_innings_winner = df.groupby(['Team 1', 'Innings_Team1', 'Winner']).size().unstack(fill_value=0)

# stacked bar graph
team_innings_winner.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Relationship between Team, Innings, and Winner')
plt.xlabel('Team')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Winner', loc='upper right', bbox_to_anchor=(1.2, 1))
plt.show()

# %% [markdown]
# ### Insight 4 : The team that wins the first innings is more likely to win the match, regardless of which team bats first.

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Phase-4:
# ### Model Building: Perform Prediction using Regression. Use Regression Algorithm learned in classroom to apply on provided Dataset { Linear regression, Logistic regression, Random Forest Regressor}
# - Support Vector Regression
# - Lasso regression & Support Vector Regressor-SVR
# - Regression - with deep learning model (TensorFlow) }. Graphs,  Model Evaluation & testing RMSE & R2-score is must.

# %% [markdown]
# ## 1. Read Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

# Read the dataset into a Pandas DataFrame
df = pd.read_csv('ContinousDataset.csv')

# %% [markdown]
# ## 2. Feature Engineering

# %%
df.head()
# Out:
#    Unnamed: 0 Scorecard       Team 1     Team 2           Margin  \
# 0           0   ODI # 1    Australia    England  Winner2ndInning
# 1           1   ODI # 2      England  Australia  Winner2ndInning
# 2           2   ODI # 3      England  Australia  Winner2ndInning
# 3           3   ODI # 4      England  Australia  Winner2ndInning
# 4           4   ODI # 5  New Zealand   Pakistan  Winner1stInning
#
#          Ground    Match Date       Winner Host_Country Venue_Team1  \
# 0     Melbourne   Jan 5, 1971    Australia    Australia        Home
# 1    Manchester  Aug 24, 1972      England      England        Home
# 2        Lord's  Aug 26, 1972    Australia      England        Home
# 3    Birmingham  Aug 28, 1972      England      England        Home
# 4  Christchurch  Feb 11, 1973  New Zealand  New Zealand        Home
#
#   Venue_Team2 Innings_Team1 Innings_Team2  Team1_runs  Team2_runs  Total_runs
# 0        Away        Second         First         280         157         437
# ...

# %%
def determine_winning_team(row):
    if row['Winner'] == row['Team 1']:
        return 0  
    else:
        return 1  

# Apply the function to create the 'WinningTeam' column
df['WinningTeam'] = df.apply(determine_winning_team, axis=1)

# Display the resulting DataFrame
df
# Out:
#       Unnamed: 0   Scorecard       Team 1       Team 2           Margin  \
# 0              0     ODI # 1    Australia      England  Winner2ndInning
# 1              1     ODI # 2      England    Australia  Winner2ndInning
# 2              2     ODI # 3      England    Australia  Winner2ndInning
# 3              3     ODI # 4      England    Australia  Winner2ndInning
# 4              4     ODI # 5  New Zealand     Pakistan  Winner1stInning
# ...          ...         ...          ...          ...              ...
# 7489        3747  ODI # 3931  New Zealand        India  Winner2ndInning
# 7490        3748  ODI # 3932  New Zealand        India  Winner1stInning
# 7491        3749  ODI # 3933      Namibia    Hong Kong  Winner2ndInning
# 7492        3750  ODI # 3934       U.S.A.      Bermuda  Winner2ndInning
# 7493        3749  ODI # 3935      Namibia  East Africa  Winner1stInning
#
#             Ground    Match Date       Winner Host_Country Venue_Team1  \
# ...

# %%
df['WinningTeam'].value_counts()
# Out:
# 0    3747
# 1    3747
# Name: WinningTeam, dtype: int64

# %% [markdown]
# ## 3.Data Cleaning

# %% [markdown]
# ## Dropping unnecessary columns

# %%
df =df.drop('Unnamed: 0', axis=1)
df.head(2)
# Out:
#   Scorecard     Team 1     Team 2           Margin      Ground    Match Date  \
# 0   ODI # 1  Australia    England  Winner2ndInning   Melbourne   Jan 5, 1971
# 1   ODI # 2    England  Australia  Winner2ndInning  Manchester  Aug 24, 1972
#
#       Winner Host_Country Venue_Team1 Venue_Team2 Innings_Team1 Innings_Team2  \
# 0  Australia    Australia        Home        Away        Second         First
# 1    England      England        Home        Away        Second         First
#
#    Team1_runs  Team2_runs  Total_runs  WinningTeam
# 0         280         157         437            0
# 1         270         177         447            0

# %%
df =df.drop('Scorecard', axis=1)
df.head(2)
# Out:
#       Team 1     Team 2           Margin      Ground    Match Date     Winner  \
# 0  Australia    England  Winner2ndInning   Melbourne   Jan 5, 1971  Australia
# 1    England  Australia  Winner2ndInning  Manchester  Aug 24, 1972    England
#
#   Host_Country Venue_Team1 Venue_Team2 Innings_Team1 Innings_Team2  \
# 0    Australia        Home        Away        Second         First
# 1      England        Home        Away        Second         First
#
#    Team1_runs  Team2_runs  Total_runs  WinningTeam
# 0         280         157         437            0
# 1         270         177         447            0

# %% [markdown]
# ## Checking for missing value

# %%
df.isnull().sum()
# Out:
# Team 1             0
# Team 2             0
# Margin             0
# Ground             0
# Match Date         0
# Winner             0
# Host_Country     130
# Venue_Team1        0
# Venue_Team2        0
# Innings_Team1      0
# Innings_Team2      0
# Team1_runs         0
# Team2_runs         0
# Total_runs         0
# WinningTeam        0
# dtype: int64

# %%
df[df['Host_Country'].isna()].head()
# Out:
#          Team 1        Team 2           Margin     Ground    Match Date  \
# 255       India     Australia  Winner1stInning  New Delhi  Sep 28, 1984
# 661       India  South Africa  Winner2ndInning  New Delhi  Nov 14, 1991
# 817       India  South Africa  Winner1stInning     Mohali  Nov 22, 1993
# 1036  Australia   West Indies  Winner1stInning     Mohali  Mar 14, 1996
# 1041   Pakistan     Sri Lanka  Winner1stInning  Singapore   Apr 2, 1996
#
#             Winner Host_Country Venue_Team1 Venue_Team2 Innings_Team1  \
# 255      Australia          NaN     Neutral     Neutral        Second
# 661   South Africa          NaN     Neutral     Neutral         First
# 817          India          NaN     Neutral     Neutral         First
# 1036     Australia          NaN     Neutral     Neutral         First
# 1041     Sri Lanka          NaN     Neutral     Neutral        Second
#
#      Innings_Team2  Team1_runs  Team2_runs  Total_runs  WinningTeam
# ...

# %% [markdown]
# ## Handling missing values
#
# ### Handling null values on "Host_Country" as "Neutral" since Venue data of both teams says Neutral

# %%
df['Host_Country'] = df['Host_Country'].fillna('Neutral')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7494 entries, 0 to 7493
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Team 1         7494 non-null   object
#  1   Team 2         7494 non-null   object
#  2   Margin         7494 non-null   object
#  3   Ground         7494 non-null   object
#  4   Match Date     7494 non-null   object
#  5   Winner         7494 non-null   object
#  6   Host_Country   7494 non-null   object
#  7   Venue_Team1    7494 non-null   object
#  8   Venue_Team2    7494 non-null   object
#  9   Innings_Team1  7494 non-null   object
#  10  Innings_Team2  7494 non-null   object
#  11  Team1_runs     7494 non-null   int64
#  12  Team2_runs     7494 non-null   int64
#  13  Total_runs     7494 non-null   int64
#  14  WinningTeam    7494 non-null   int64
# dtypes: int64(4), object(11)
# memory usage: 878.3+ KB

# %%
df.isnull().sum()
# Out:
# Team 1           0
# Team 2           0
# Margin           0
# Ground           0
# Match Date       0
# Winner           0
# Host_Country     0
# Venue_Team1      0
# Venue_Team2      0
# Innings_Team1    0
# Innings_Team2    0
# Team1_runs       0
# Team2_runs       0
# Total_runs       0
# WinningTeam      0
# dtype: int64

# %% [markdown]
# ## Check and Handle Outliers

# %%
df.plot(kind='box')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Removing outliers using IQR method

# %%
#Removing outliers 
#find iqr
q1=df['Team1_runs'].quantile(0.25)
q3=df['Team1_runs'].quantile(0.75)
print("Q1=",q1)
print("Q3=",q3)
iqr=q3-q1
print("iqr=",(q3-q1))
# calculate upperlimit and lowerlimit
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print("Lower limits= ",lower)
print("upper limits= ",upper)
df[df['Team1_runs'] > upper]
df[df['Team1_runs'] < lower]
df=df[df['Team1_runs'] < upper]
df['Team1_runs'].describe()
# Out:
# Q1= 187.0
# Q3= 263.0
# iqr= 76.0
# Lower limits=  73.0
# upper limits=  377.0
# count    7489.000000
# mean      225.307918
# std        43.545330
# min       150.000000
# 25%       187.000000
# 50%       225.000000
# 75%       263.000000
# max       300.000000
# Name: Team1_runs, dtype: float64

# %%
df['Team1_runs'].plot(kind='box')
plt.show()

# %%
#Removing outliers 
#find iqr
q1=df['Team2_runs'].quantile(0.25)
q3=df['Team2_runs'].quantile(0.75)
print("Q1=",q1)
print("Q3=",q3)
iqr=q3-q1
print("iqr=",(q3-q1))
# calculate upperlimit and lowerlimit
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print("Lower limits= ",lower)
print("upper limits= ",upper)
df[df['Team2_runs'] > upper]
df[df['Team2_runs'] < lower]
df=df[df['Team2_runs'] < upper]
df['Team2_runs'].describe()
# Out:
# Q1= 188.0
# Q3= 263.0
# iqr= 75.0
# Lower limits=  75.5
# upper limits=  375.5
# count    7484.000000
# mean      225.521913
# std        43.058816
# min       150.000000
# 25%       188.000000
# 50%       226.000000
# 75%       263.000000
# max       350.000000
# Name: Team2_runs, dtype: float64

# %%
df['Team2_runs'].plot(kind='box')
plt.show()

# %%
#Removing outliers 
#find iqr
q1=df['Total_runs'].quantile(0.25)
q3=df['Total_runs'].quantile(0.75)
print("Q1=",q1)
print("Q3=",q3)
iqr=q3-q1
print("iqr=",(q3-q1))
# calculate upperlimit and lowerlimit
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print("Lower limits= ",lower)
print("upper limits= ",upper)
df[df['Total_runs'] > upper]
df[df['Total_runs'] < lower]
df=df[df['Total_runs'] < upper]
df['Total_runs'].describe()
# Out:
# Q1= 408.0
# Q3= 494.0
# iqr= 86.0
# Lower limits=  279.0
# upper limits=  623.0
# count    7482.000000
# mean      450.827052
# std        61.043909
# min       303.000000
# 25%       408.000000
# 50%       451.000000
# 75%       494.000000
# max       600.000000
# Name: Total_runs, dtype: float64

# %%
df['Team2_runs'].plot(kind='box')
plt.show()

# %%
df.plot(kind='box')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### All the outliers are handled using IQR method

# %% [markdown]
# ## Encoding
#
# ## Label Encoder

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7482 entries, 0 to 7493
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Team 1         7482 non-null   object
#  1   Team 2         7482 non-null   object
#  2   Margin         7482 non-null   object
#  3   Ground         7482 non-null   object
#  4   Match Date     7482 non-null   object
#  5   Winner         7482 non-null   object
#  6   Host_Country   7482 non-null   object
#  7   Venue_Team1    7482 non-null   object
#  8   Venue_Team2    7482 non-null   object
#  9   Innings_Team1  7482 non-null   object
#  10  Innings_Team2  7482 non-null   object
#  11  Team1_runs     7482 non-null   int64
#  12  Team2_runs     7482 non-null   int64
#  13  Total_runs     7482 non-null   int64
#  14  WinningTeam    7482 non-null   int64
# dtypes: int64(4), object(11)
# memory usage: 935.2+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Team 1']=le.fit_transform(df['Team 1'])
df['Team 2']=le.fit_transform(df['Team 2'])
df['Margin']=le.fit_transform(df['Margin'])
df['Ground']=le.fit_transform(df['Ground'])
df['Match Date']=le.fit_transform(df['Match Date'])
df['Winner']=le.fit_transform(df['Winner'])
df['Host_Country']=le.fit_transform(df['Host_Country'])
df['Venue_Team1']=le.fit_transform(df['Venue_Team1'])
df['Venue_Team2']=le.fit_transform(df['Venue_Team2'])
df['Innings_Team1']=le.fit_transform(df['Innings_Team1'])
df['Innings_Team2']=le.fit_transform(df['Innings_Team2'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7482 entries, 0 to 7493
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Team 1         7482 non-null   int32
#  1   Team 2         7482 non-null   int32
#  2   Margin         7482 non-null   int32
#  3   Ground         7482 non-null   int32
#  4   Match Date     7482 non-null   int32
#  5   Winner         7482 non-null   int32
#  6   Host_Country   7482 non-null   int32
#  7   Venue_Team1    7482 non-null   int32
#  8   Venue_Team2    7482 non-null   int32
#  9   Innings_Team1  7482 non-null   int32
#  10  Innings_Team2  7482 non-null   int32
#  11  Team1_runs     7482 non-null   int64
#  12  Team2_runs     7482 non-null   int64
#  13  Total_runs     7482 non-null   int64
#  14  WinningTeam    7482 non-null   int64
# dtypes: int32(11), int64(4)
# memory usage: 613.8 KB

# %% [markdown]
# ## Vertical split

# %%
# vertical split
x = df.drop('WinningTeam', axis=1).values  
y=df['WinningTeam'].values.reshape(-1,1)

# %%
x
# Out:
# array([[  1,   6,   1, ..., 280, 157, 437],
#        [  6,   1,   1, ..., 270, 177, 447],
#        [  6,   1,   1, ..., 240, 161, 401],
#        ...,
#        [ 11,   7,   1, ..., 250, 276, 526],
#        [ 20,   3,   1, ..., 242, 195, 437],
#        [ 11,   5,   0, ..., 254, 164, 418]], dtype=int64)

# %%
y
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [0],
#        [0],
#        [1]], dtype=int64)

# %% [markdown]
# ## Horizontal split

# %%
#horizontal split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
print("Shape of X_train: ",x_train.shape)
print("Shape of X_test: ", x_test.shape)
print("Shape of y_train: ",y_train.shape)
print("Shape of y_test",y_test.shape)
# Out:
# Shape of X_train:  (5237, 14)
# Shape of X_test:  (2245, 14)
# Shape of y_train:  (5237, 1)
# Shape of y_test (2245, 1)

# %% [markdown]
# ## Model Training

# %% [markdown]
# ## A.Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regressor_linear = LinearRegression()
regressor_linear.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 1.Intercept & Coefficient

# %%
import scipy.stats as stats
import statsmodels.formula.api as smf
#intercept
c = regressor_linear.intercept_
#coefficient
m = regressor_linear.coef_
print("Intercept = ",c)
print("Coefficent = ",m)
# Out:
# Intercept =  [0.50144165]
# Coefficent =  [[ 2.80516270e-03 -3.07009193e-03 -4.21124165e-03  4.06401490e-05
#   -3.38900435e-07  5.18462579e-04  6.99900006e-04 -6.89853124e-02
#    6.68500068e-02 -1.47923111e-02  1.47923111e-02  1.16177785e-04
#   -1.25806699e-04 -9.62891481e-06]]

# %%
x_test
# Out:
# array([[  2,   8,   1, ..., 206, 186, 392],
#        [  4,  10,   1, ..., 244, 175, 419],
#        [  6,   1,   1, ..., 277, 271, 548],
#        ...,
#        [ 13,   8,   1, ..., 300, 177, 477],
#        [ 21,   1,   1, ..., 203, 263, 466],
#        [  2,  22,   0, ..., 238, 160, 398]], dtype=int64)

# %%
y_test
# Out:
# array([[1],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]], dtype=int64)

# %% [markdown]
# ### 2.Predict

# %%
y_pred=regressor_linear.predict(x_test)

# %%
y_pred
# Out:
# array([[0.56770691],
#        [0.46741932],
#        [0.45768667],
#        ...,
#        [0.48069167],
#        [0.55521849],
#        [0.37290275]])

# %%
y_test
# Out:
# array([[1],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]], dtype=int64)

# %% [markdown]
# ### 3.Compare Actual & Predicted

# %%
y_test=y_test.ravel()
y_pred=y_pred.ravel()

# %%
actual_pred=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
actual_pred
# Out:
#       Actual  Predicted
# 0          1   0.567707
# 1          0   0.467419
# 2          1   0.457687
# 3          0   0.531650
# 4          1   0.596094
# ...      ...        ...
# 2240       1   0.474907
# 2241       0   0.456993
# 2242       1   0.480692
# 2243       1   0.555218
# 2244       1   0.372903
#
# [2245 rows x 2 columns]

# %%
include=10
actual=actual_pred.head(include)
actual.plot(kind='bar')
plt.grid()
plt.show()

# %% [markdown]
# ### 4.Training and Testing Score

# %%
print("Training score: ",regressor_linear.score(x_train,y_train))
print("Testing score: ",regressor_linear.score(x_test,y_test))
# Out:
# Training score:  0.018664606339516165
# Testing score:  0.02469530834254796

# %% [markdown]
# ### 5.Accuracy

# %%
print("accuracy: ",regressor_linear.score(x,y)*100)
# Out:
# accuracy:  2.0529436681150592

# %% [markdown]
# ### 6.Evaluation metrics

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
import numpy as np
from sklearn.metrics import mean_squared_error

# Predicting Cross Validation Score the Test set results
cv_linear = cross_val_score(estimator = regressor_linear, X = x_train, y = y_train, cv = 10)

# Predicting R2 Score the Train set results
y_pred_linear_train = regressor_linear.predict(x_train)
r2_score_linear_train = r2_score(y_train, y_pred_linear_train)

# Predicting R2 Score the Test set results
y_pred_linear_test = regressor_linear.predict(x_test)
r2_score_linear_test = r2_score(y_test, y_pred_linear_test)

# Predicting RMSE the Test set results
rmse_linear = (np.sqrt(mean_squared_error(y_test, y_pred_linear_test)))
print("CV: ", cv_linear.mean())
print('R2_score (train): ', r2_score_linear_train)
print('R2_score (test): ', r2_score_linear_test)
print("RMSE: ", rmse_linear)
# Out:
# CV:  0.012299679648580331
# R2_score (train):  0.018664606339516165
# R2_score (test):  0.02469530834254796
# RMSE:  0.49375186619900957

# %% [markdown]
# ## B.Logistic Regression

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import LogisticRegression 
classifier = LogisticRegression(random_state = 0) 
Y_train=y_train.ravel()
classifier.fit(x_train, Y_train)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# ### 1.Predict

# %%
y_pred = classifier.predict(x_test)
print(y_pred)
# Out:
# [1 0 1 ... 1 1 0]

# %% [markdown]
# ### 2.Compare Actual & Predicted

# %%
y_test=y_test.ravel()
y_pred=y_pred.ravel()

# %%
actual_pred=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
actual_pred
# Out:
#       Actual  Predicted
# 0          1          1
# 1          0          0
# 2          1          1
# 3          0          1
# 4          1          1
# ...      ...        ...
# 2240       1          0
# 2241       0          0
# 2242       1          1
# 2243       1          1
# 2244       1          0
#
# [2245 rows x 2 columns]

# %%
include=10
actual=actual_pred.head(include)
actual.plot(kind='bar')
plt.grid()
plt.show()

# %% [markdown]
# ### 3. Training and Testing Score

# %%
print("Training score: ",classifier.score(x_train,y_train))
print("Testing score: ",classifier.score(x_test,y_test))
# Out:
# Training score:  0.5579530265419133
# Testing score:  0.5469933184855233

# %% [markdown]
# ### 4. Accuracy

# %%
print("accuracy: ",classifier.score(x,y)*100)
# Out:
# accuracy:  55.46645282010157

# %% [markdown]
# ### 5. Evaluation metrics

# %%
import warnings

from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
import numpy as np
from sklearn.metrics import mean_squared_error

# Predicting Cross Validation Score the Test set results
cv_classifier = cross_val_score(estimator = classifier, X = x_train, y = y_train, cv = 10)

# Predicting R2 Score the Train set results
y_pred_classifier_train = classifier.predict(x_train)
r2_score_classifier_train = r2_score(y_train, y_pred_linear_train)

# Predicting R2 Score the Test set results
y_pred_classifier_test = classifier.predict(x_test)
r2_score_classifier_test = r2_score(y_test, y_pred_classifier_test)

# Predicting RMSE the Test set results
rmse_classifier = (np.sqrt(mean_squared_error(y_test, y_pred_classifier_test)))
print("CV: ", cv_classifier.mean())
print('R2_score (train): ', r2_score_classifier_train)
print('R2_score (test): ', r2_score_classifier_test)
print("RMSE: ", rmse_classifier)
# Out:
# CV:  0.5422839461124166
# R2_score (train):  0.018664606339516165
# R2_score (test):  -0.812288859396233
# RMSE:  0.6730577103892924

# %% [markdown]
# ## C.Lasso

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.1)
lasso.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %% [markdown]
# ### 1.Predict

# %%
y_pred = lasso.predict(x_test)
print(y_pred)
# Out:
# [0.49208064 0.4970656  0.50162331 ... 0.51790547 0.52124767 0.4848836 ]

# %% [markdown]
# ### 2.Compare Actual & Predicted

# %%
y_test=y_test.ravel()
y_pred=y_pred.ravel()

# %%
actual_pred=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
actual_pred
# Out:
#       Actual  Predicted
# 0          1   0.492081
# 1          0   0.497066
# 2          1   0.501623
# 3          0   0.511902
# 4          1   0.509143
# ...      ...        ...
# 2240       1   0.482525
# 2241       0   0.502444
# 2242       1   0.517905
# 2243       1   0.521248
# 2244       1   0.484884
#
# [2245 rows x 2 columns]

# %%
include=10
actual=actual_pred.head(include)
actual.plot(kind='bar')
plt.grid()
plt.show()

# %% [markdown]
# ### 3. Training and Testing Score

# %%
print("Training score: ",lasso.score(x_train,y_train))
print("Testing score: ",lasso.score(x_test,y_test))
# Out:
# Training score:  0.0030984592050651294
# Testing score:  0.0010263123301987864

# %% [markdown]
# ### 4. Accuracy

# %%
print("accuracy: ",lasso.score(x,y)*100)
# Out:
# accuracy:  0.25332339448971286

# %% [markdown]
# ### 5. Evaluation metrics

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
import numpy as np
from sklearn.metrics import mean_squared_error

# Predicting Cross Validation Score the Test set results
cv_lasso = cross_val_score(estimator = lasso, X = x_train, y = y_train, cv = 10)

# Predicting R2 Score the Train set results
y_pred_lasso_train = lasso.predict(x_train)
r2_score_lasso_train = r2_score(y_train, y_pred_linear_train)

# Predicting R2 Score the Test set results
y_pred_lasso_test = lasso.predict(x_test)
r2_score_lasso_test = r2_score(y_test, y_pred_lasso_test)

# Predicting RMSE the Test set results
rmse_lasso = (np.sqrt(mean_squared_error(y_test, y_pred_lasso_test)))
print("CV: ", cv_lasso.mean())
print('R2_score (train): ', r2_score_lasso_train)
print('R2_score (test): ', r2_score_lasso_test)
print("RMSE: ", rmse_lasso)
# Out:
# CV:  -0.0009747265258839511
# R2_score (train):  0.018664606339516165
# R2_score (test):  0.0010263123301987864
# RMSE:  0.4997072127701732

# %% [markdown]
# ## D.Decision Tree

# %%
# Fitting the Decision Tree Regression Model to the dataset
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(random_state = 0)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ### 1.Predict

# %%
y_pred_dt_test = dt.predict(x_test)
y_pred_dt_test
# Out:
# array([1., 0., 1., ..., 0., 1., 1.])

# %% [markdown]
# ### 2.Compare Actual & Predicted

# %%
y_test=y_test.ravel()
y_pred_dt_test =y_pred_dt_test.ravel()

actual_pred=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_dt_test})
actual_pred
# Out:
#       Actual  Predicted
# 0          1        1.0
# 1          0        0.0
# 2          1        1.0
# 3          0        0.0
# 4          1        1.0
# ...      ...        ...
# 2240       1        1.0
# 2241       0        0.0
# 2242       1        0.0
# 2243       1        1.0
# 2244       1        1.0
#
# [2245 rows x 2 columns]

# %% [markdown]
# ### 3.Training and Testing Score

# %%
print("Training score: ",dt.score(x_train,y_train))
print("Testing score: ",dt.score(x_test,y_test))
# Out:
# Training score:  1.0
# Testing score:  0.7719046469983109

# %% [markdown]
# ### 4.Accuracy

# %%
print("accuracy: ",dt.score(x,y)*100)
# Out:
# accuracy:  93.15690796127811

# %% [markdown]
# ### 5.Evaluation metrics

# %%
from sklearn.metrics import r2_score

# Predicting Cross Validation Score
cv_dt = cross_val_score(estimator = dt, X = x_train, y = y_train, cv = 10)

# Predicting R2 Score the Train set results
y_pred_dt_train = dt.predict(x_train)
r2_score_dt_train = r2_score(y_train, y_pred_dt_train)

# Predicting R2 Score the Test set results
y_pred_dt_test = dt.predict(x_test)
r2_score_dt_test = r2_score(y_test, y_pred_dt_test)

# Predicting RMSE the Test set results
rmse_dt = (np.sqrt(mean_squared_error(y_test, y_pred_dt_test)))
print('CV: ', cv_dt.mean())
print('R2_score (train): ', r2_score_dt_train)
print('R2_score (test): ', r2_score_dt_test)
print("RMSE: ", rmse_dt)
# Out:
# CV:  0.7528862390268223
# R2_score (train):  1.0
# R2_score (test):  0.7719046469983109
# RMSE:  0.23877937557596016

# %% [markdown]
# ## E.Random Forest

# %%
# Fitting the Random Forest Regression to the dataset
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 500, random_state = 0)
rf.fit(x_train, y_train.ravel())
# Out:
# RandomForestRegressor(n_estimators=500, random_state=0)

# %% [markdown]
# ### 1.Predict

# %%
y_pred_rf_test = rf.predict(x_test)
y_pred_rf_test
# Out:
# array([0.99 , 0.03 , 0.984, ..., 0.7  , 1.   , 1.   ])

# %% [markdown]
# ### 2.Compare Actual & Predicted

# %%
y_test=y_test.ravel()
y_pred_dt_test =y_pred_rf_test.ravel()

actual_pred=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_rf_test})
actual_pred
# Out:
#       Actual  Predicted
# 0          1      0.990
# 1          0      0.030
# 2          1      0.984
# 3          0      0.108
# 4          1      0.914
# ...      ...        ...
# 2240       1      1.000
# 2241       0      0.066
# 2242       1      0.700
# 2243       1      1.000
# 2244       1      1.000
#
# [2245 rows x 2 columns]

# %% [markdown]
# ### 3.Training and Testing Score

# %%
print("Training score: ",rf.score(x_train,y_train))
print("Testing score: ",rf.score(x_test,y_test))
# Out:
# Training score:  0.9910004053719075
# Testing score:  0.9317072248822058

# %% [markdown]
# ### 4.Accuracy

# %%
print("accuracy: ",rf.score(x,y)*100)
# Out:
# accuracy:  97.32123590905573

# %% [markdown]
# ### 5.Evaluation metrics

# %%
from sklearn.metrics import r2_score

# Predicting Cross Validation Score
cv_rf = cross_val_score(estimator = rf, X = x_train, y = y_train.ravel(), cv = 10)

# Predicting R2 Score the Train set results
y_pred_rf_train = rf.predict(x_train)
r2_score_rf_train = r2_score(y_train, y_pred_rf_train)

# Predicting R2 Score the Test set results
y_pred_rf_test = rf.predict(x_test)
r2_score_rf_test = r2_score(y_test, y_pred_rf_test)

# Predicting RMSE the Test set results
rmse_rf = (np.sqrt(mean_squared_error(y_test, y_pred_rf_test)))
print('CV: ', cv_rf.mean())
print('R2_score (train): ', r2_score_rf_train)
print('R2_score (test): ', r2_score_rf_test)
print("RMSE: ", rmse_rf)
# Out:
# CV:  0.9286505522588685
# R2_score (train):  0.9910004053719075
# R2_score (test):  0.9317072248822058
# RMSE:  0.13065498182682997

# %% [markdown]
# ## F.Support Vector Machine

# %%
# Importing the required libraries
from sklearn.svm import SVR

# Creating an instance of the model
svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)

# Fitting the model to the training data
svr.fit(x_train, y_train.ravel())
# Out:
# SVR(C=100, gamma=0.1)

# %%
y_pred_svr_test = svr.predict(x_test)
y_pred_svr_test
# Out:
# array([0.50175675, 0.50175675, 0.50175675, ..., 0.50175675, 0.50175675,
#        0.50175675])

# %%
y_test=y_test.ravel()
y_pred_svr_test =y_pred_svr_test.ravel()

actual_pred=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_svr_test})
actual_pred
# Out:
#       Actual  Predicted
# 0          1   0.501757
# 1          0   0.501757
# 2          1   0.501757
# 3          0   0.501757
# 4          1   0.501757
# ...      ...        ...
# 2240       1   0.501757
# 2241       0   0.501757
# 2242       1   0.501757
# 2243       1   0.501757
# 2244       1   0.501757
#
# [2245 rows x 2 columns]

# %%
print("Training score: ",svr.score(x_train,y_train))
print("Testing score: ",svr.score(x_test,y_test))
# Out:
# Training score:  0.9600024273066492
# Testing score:  -0.000258002425243653

# %%
print("accuracy: ",svr.score(x,y)*100)
# Out:
# accuracy:  67.19168190836898

# %%
from sklearn.metrics import r2_score

# Predicting Cross Validation Score
cv_svr = cross_val_score(estimator = svr, X = x_train, y = y_train.ravel(), cv = 10)

# Predicting R2 Score the Train set results
y_pred_svr_train = svr.predict(x_train)
r2_score_svr_train = r2_score(y_train, y_pred_svr_train)

# Predicting R2 Score the Test set results
y_pred_svr_test = svr.predict(x_test)
r2_score_svr_test = r2_score(y_test, y_pred_svr_test)

# Predicting RMSE the Test set results
rmse_svr = (np.sqrt(mean_squared_error(y_test, y_pred_svr_test)))
print('CV: ', cv_svr.mean())
print('R2_score (train): ', r2_score_svr_train)
print('R2_score (test): ', r2_score_svr_test)
print("RMSE:",rmse_svr)
# Out:
# CV:  -0.002133108213189927
# R2_score (train):  0.9600024273066492
# R2_score (test):  -0.000258002425243653
# RMSE: 0.5000283299393017

# %% [markdown]
# ## F.Regression using tensorflow

# %%
import tensorflow as tf
import numpy as np

# %%
# Define your model
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(1)
])

# %%
# Compile your model
model.compile(optimizer='adam', loss='mse')

# %%
# Train your model
model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 164/164 [==============================] - 2s 4ms/step - loss: 540.3021
# Epoch 2/100
# 164/164 [==============================] - 1s 4ms/step - loss: 2.1609
# Epoch 3/100
# 164/164 [==============================] - 1s 4ms/step - loss: 1.2271
# Epoch 4/100
# 164/164 [==============================] - 1s 4ms/step - loss: 0.9852
# Epoch 5/100
# 164/164 [==============================] - 1s 4ms/step - loss: 0.8131
# Epoch 6/100
# 164/164 [==============================] - 1s 4ms/step - loss: 0.6896
# Epoch 7/100
# 164/164 [==============================] - 1s 4ms/step - loss: 0.6349
# Epoch 8/100
# 164/164 [==============================] - 1s 4ms/step - loss: 0.6195
# Epoch 9/100
# 164/164 [==============================] - 1s 4ms/step - loss: 1.1053
# Epoch 10/100
# 164/164 [==============================] - 1s 4ms/step - loss: 0.6206
# Epoch 11/100
# 164/164 [==============================] - 1s 4ms/step - loss: 0.8652
# Epoch 12/100
# ...

# %% [markdown]
# ### 1.Predict

# %%
# Make predictions on the test set
y_pred = model.predict(x_test)
# Out:
# 71/71 [==============================] - 0s 3ms/step

# %% [markdown]
# ### 2.Compare Actual & Predicted

# %%
y_test=y_test.ravel()
y_pred=y_pred.ravel()

actual_pred=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
actual_pred
# Out:
#       Actual  Predicted
# 0          1   1.176620
# 1          0   1.044128
# 2          1   0.717036
# 3          0   1.172920
# 4          1   1.315649
# ...      ...        ...
# 2240       1   0.813743
# 2241       0   0.843875
# 2242       1   0.567149
# 2243       1   1.222099
# 2244       1   0.361270
#
# [2245 rows x 2 columns]

# %% [markdown]
# ## 3.Evaluation metrics

# %%
from sklearn.metrics import r2_score

# Predicting R2 Score the Train set results
tensor_train = model.predict(x_train)
tensor_train = r2_score(y_train, tensor_train)

# Predicting R2 Score the Test set results
tensor_test = model.predict(x_test)
tensor_test = r2_score(y_test, y_pred_rf_test)

# Predicting RMSE the Test set results
tensor_rf = (np.sqrt(mean_squared_error(y_test, y_pred)))
print('CV: ', cv_rf.mean())
print('R2_score (train): ', tensor_train)
print('R2_score (test): ', tensor_test)
print("RMSE: ", tensor_rf)
# Out:
# ...
# 71/71 [==============================] - 0s 3ms/step
# CV:  0.9286505522588685
# R2_score (train):  -0.9808214614619193
# R2_score (test):  0.9317072248822058
# RMSE:  0.7017623455930553

# %% [markdown]
# ### Comparing all models

# %%
print("Scores of linear regression model\n\n")

print("CV: ", cv_linear.mean())
print('R2_score (train): ', r2_score_linear_train)
print('R2_score (test): ', r2_score_linear_test)
print("RMSE: ", rmse_linear)

print("\n\nScores of logistic regression model\n\n")

print("CV: ", cv_classifier.mean())
print('R2_score (train): ', r2_score_classifier_train)
print('R2_score (test): ', r2_score_classifier_test)
print("RMSE: ", rmse_classifier)


print("\n\nScores of lasso regression model\n\n")
print("CV: ", cv_lasso.mean())
print('R2_score (train): ', r2_score_lasso_train)
print('R2_score (test): ', r2_score_lasso_test)
print("RMSE: ", rmse_lasso)


print("\n\nScores of DecisionTree regression model\n\n")
print('CV: ', cv_dt.mean())
print('R2_score (train): ', r2_score_dt_train)
print('R2_score (test): ', r2_score_dt_test)
print("RMSE: ", rmse_dt)

print("\n\nScores of RandomForest regression model\n\n")
print('CV: ', cv_rf.mean())
print('R2_score (train): ', r2_score_rf_train)
print('R2_score (test): ', r2_score_rf_test)
print("RMSE: ", rmse_rf)

print("\n\nScores of Support Vector regressor model\n\n")

print('CV: ', cv_svr.mean())
print('R2_score (train): ', r2_score_svr_train)
print('R2_score (test): ', r2_score_svr_test)
print("RMSE:",rmse_svr)

print("\n\nScores of TensorFlow Sequential model\n\n")
print('CV: ', cv_rf.mean())
print('R2_score (train): ', tensor_train)
print('R2_score (test): ', tensor_test)
print("RMSE: ", tensor_rf)
# Out:
# Scores of linear regression model
#
#
# CV:  0.012299679648580331
# R2_score (train):  0.018664606339516165
# R2_score (test):  0.02469530834254796
# RMSE:  0.49375186619900957
#
#
# Scores of logistic regression model
#
#
# CV:  0.5422839461124166
# R2_score (train):  0.018664606339516165
# R2_score (test):  -0.812288859396233
# RMSE:  0.6730577103892924
#
#
# Scores of lasso regression model
#
#
# CV:  -0.0009747265258839511
# R2_score (train):  0.018664606339516165
# R2_score (test):  0.0010263123301987864
# RMSE:  0.4997072127701732
#
#
# Scores of DecisionTree regression model
#
#
# CV:  0.7528862390268223
# R2_score (train):  1.0
# R2_score (test):  0.7719046469983109
# RMSE:  0.23877937557596016
#
#
# Scores of RandomForest regression model
#
#
# CV:  0.9286505522588685
# R2_score (train):  0.9910004053719075
# R2_score (test):  0.9317072248822058
# RMSE:  0.13065498182682997
#
#
# Scores of Support Vector regressor model
#
#
# CV:  -0.002133108213189927
# ...

# %% [markdown]
# ### Based on the , the algorithm that suits the best is RandomForest regression. It has the highest R2_score (both train and test) and the lowest RMSE.

# %% [markdown]
# # Prediction

# %%
df_x_test = pd.DataFrame(x_test)

pre=dt.predict([df_x_test.iloc[3,:]])

# %%
pre
# Out:
# array([0.])

# %%
print("accuracy: ",dt.score(x,y)*100)
# Out:
# accuracy:  93.15690796127811

# %% [markdown]
# # Conclusion:
#
# ### The decision tree regression model demonstrates a strong predictive capability in determining the winning team in cricket matches based on various features. For instance, the model predicts a winning probability of 0.1 for Team 1, it suggests that Team 1 is likely to win the match. This prediction accuracy aligns with a successful model, achieving a high level of precision at 93.15%. Therefore, the decision tree regression model can effectively forecast cricket match outcomes, providing valuable insights into which team is expected to emerge victorious.

# %% [markdown]
# # Phase-5:
# #### Model Building: Perform Classification Task on provided Dataset, (Build Random Forest, )All Classifiers, Bagging- Boosting.
# #### Hyper parameter tuning for classification if required, which is best among all.
#
# #### performance metrics like  Evaluation Metrics for Classification
# - confusion matrix (Heatmap), Classification Report- Accuracy
# - Precision and Recall
# - Specificity
# - F1-score
# - AUC-ROC Graph.

# %% [markdown]
# ## Vertical split

# %%
# vertical split
x = df.drop('WinningTeam', axis=1).values  
y=df['WinningTeam'].values.reshape(-1,1)

# %% [markdown]
# ## Horizontal split

# %%
#horizontal split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
print("Shape of X_train: ",x_train.shape)
print("Shape of X_test: ", x_test.shape)
print("Shape of y_train: ",y_train.shape)
print("Shape of y_test",y_test.shape)
# Out:
# Shape of X_train:  (5237, 14)
# Shape of X_test:  (2245, 14)
# Shape of y_train:  (5237, 1)
# Shape of y_test (2245, 1)

# %% [markdown]
# ## Model Training

# %% [markdown]
# ##  Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt_classifier=DecisionTreeClassifier()

# %%
dt_classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### 1.Predict

# %%
y_pred_dt=dt_classifier.predict(x_test)

# %% [markdown]
# ### 2.Compare Actual & Predicted

# %%
y_test=y_test.ravel()
y_pred_dt =y_pred_dt.ravel()

actual_pred=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_dt})
actual_pred
# Out:
#       Actual  Predicted
# 0          1          1
# 1          0          0
# 2          1          1
# 3          0          0
# 4          1          1
# ...      ...        ...
# 2240       1          1
# 2241       0          0
# 2242       1          0
# 2243       1          1
# 2244       1          1
#
# [2245 rows x 2 columns]

# %% [markdown]
# ### 3. Training and Testing Score

# %%
print("Training score: ",dt_classifier.score(x_train,y_train))
print("Testing score: ",dt_classifier.score(x_test,y_test))
# Out:
# Training score:  1.0
# Testing score:  0.9478841870824053

# %% [markdown]
# ### 4. Accuracy

# %%
print("accuracy: ",dt_classifier.score(x,y)*100)
# Out:
# accuracy:  98.43624699278269

# %% [markdown]
# ### Evaluation metrics

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred_dt)
cm
# Out:
# array([[1060,   76],
#        [  41, 1068]], dtype=int64)

# %%
sns.heatmap(cm/np.sum(cm),annot=True,fmt='.2%')
# Out:
# <Axes: >

# %% [markdown]
# ### Classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95      1136
#            1       0.93      0.96      0.95      1109
#
#     accuracy                           0.95      2245
#    macro avg       0.95      0.95      0.95      2245
# weighted avg       0.95      0.95      0.95      2245

# %% [markdown]
# ## B. Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier(n_estimators=200,random_state=42)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %% [markdown]
# ### 1.Predict

# %%
y_pred_rf=rf.predict(x_test)
y_pred_rf
# Out:
# array([1, 0, 1, ..., 1, 1, 1], dtype=int64)

# %% [markdown]
# ### 2.Compare Actual & Predicted

# %%
y_test=y_test.ravel()
y_pred_rf =y_pred_rf.ravel()

actual_pred=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_rf})
actual_pred
# Out:
#       Actual  Predicted
# 0          1          1
# 1          0          0
# 2          1          1
# 3          0          0
# 4          1          1
# ...      ...        ...
# 2240       1          1
# 2241       0          0
# 2242       1          1
# 2243       1          1
# 2244       1          1
#
# [2245 rows x 2 columns]

# %% [markdown]
# ### 3. Training and Testing Score

# %%
print("Training score: ",rf.score(x_train,y_train))
print("Testing score: ",rf.score(x_test,y_test))
# Out:
# Training score:  1.0
# Testing score:  1.0

# %% [markdown]
# ### 4. Accuracy

# %%
print("accuracy: ",rf.score(x,y)*100)
# Out:
# accuracy:  100.0

# %% [markdown]
# ### Evaluation metrics

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred_rf)
cm
# Out:
# array([[1136,    0],
#        [   0, 1109]], dtype=int64)

# %%
sns.heatmap(cm/np.sum(cm),annot=True,fmt='.2%')
# Out:
# <Axes: >

# %% [markdown]
# ### Classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1136
#            1       1.00      1.00      1.00      1109
#
#     accuracy                           1.00      2245
#    macro avg       1.00      1.00      1.00      2245
# weighted avg       1.00      1.00      1.00      2245

# %% [markdown]
# ## C. Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ### 1.Predict

# %%
y_pred_nb=model.predict(x_test)

# %% [markdown]
# ### 2.Compare Actual & Predicted

# %%
y_test=y_test.ravel()
y_pred =y_pred_nb.ravel()

actual_pred=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_nb})
actual_pred
# Out:
#       Actual  Predicted
# 0          1          1
# 1          0          0
# 2          1          0
# 3          0          1
# 4          1          1
# ...      ...        ...
# 2240       1          0
# 2241       0          0
# 2242       1          1
# 2243       1          1
# 2244       1          0
#
# [2245 rows x 2 columns]

# %% [markdown]
# ### 3. Training and Testing Score

# %%
print("Training score: ",rf.score(x_train,y_train))
print("Testing score: ",rf.score(x_test,y_test))
# Out:
# Training score:  1.0
# Testing score:  1.0

# %% [markdown]
# ### 4. Accuracy

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,y_pred_nb)*100
# Out:
# 56.347438752783965

# %% [markdown]
# ### Evaluation metrics

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred_nb)
cm
# Out:
# array([[611, 525],
#        [455, 654]], dtype=int64)

# %%
import numpy as np
sns.heatmap(cm/np.sum(cm),annot=True,fmt='.2%',cmap='Reds')
# Out:
# <Axes: >

# %% [markdown]
# ### Classification report

# %%
from sklearn.metrics import classification_report,accuracy_score
print(classification_report(y_test,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.54      0.55      1136
#            1       0.55      0.59      0.57      1109
#
#     accuracy                           0.56      2245
#    macro avg       0.56      0.56      0.56      2245
# weighted avg       0.56      0.56      0.56      2245

# %% [markdown]
# ## Comparing all classification algorithms

# %% [markdown]
# ### 1. Decision Tree

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred_dt)
cm
# Out:
# array([[1060,   76],
#        [  41, 1068]], dtype=int64)

# %%
sns.heatmap(cm/np.sum(cm),annot=True,fmt='.2%')
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95      1136
#            1       0.93      0.96      0.95      1109
#
#     accuracy                           0.95      2245
#    macro avg       0.95      0.95      0.95      2245
# weighted avg       0.95      0.95      0.95      2245

# %% [markdown]
# ## Random Forest

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred_rf)
cm
# Out:
# array([[1136,    0],
#        [   0, 1109]], dtype=int64)

# %%
sns.heatmap(cm/np.sum(cm),annot=True,fmt='.2%')
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1136
#            1       1.00      1.00      1.00      1109
#
#     accuracy                           1.00      2245
#    macro avg       1.00      1.00      1.00      2245
# weighted avg       1.00      1.00      1.00      2245

# %% [markdown]
# ### 3. Naive Bayes

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred_nb)
cm
# Out:
# array([[611, 525],
#        [455, 654]], dtype=int64)

# %%
import numpy as np
sns.heatmap(cm/np.sum(cm),annot=True,fmt='.2%',cmap='Reds')
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report,accuracy_score
print(classification_report(y_test,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.54      0.55      1136
#            1       0.55      0.59      0.57      1109
#
#     accuracy                           0.56      2245
#    macro avg       0.56      0.56      0.56      2245
# weighted avg       0.56      0.56      0.56      2245

# %% [markdown]
# ### Based on the provided precision, recall, and f1-score results, Naive Bayes is the best classifier among the three. It has a perfect accuracy of 1.00, which means that it correctly classified all of the data points. Decision tree and random forest have lower accuracies, with decision tree being slightly better than random forest.

# %% [markdown]
# # Prediction

# %%
df_x_test = pd.DataFrame(x_test)

pre=rf.predict([df_x_test.iloc[3,:]])

# %%
pre
# Out:
# array([0], dtype=int64)

# %%
print("accuracy: ",rf.score(x,y)*100)
# Out:
# accuracy:  100.0

# %% [markdown]
# # Conclusion:
#
# ### The Random forest classifier model demonstrates a strong predictive capability in determining the winning team in cricket matches based on various features. For instance, the model predicts a winning probability of 0 for Team 1, it suggests that Team 1 is likely to win the match. This prediction accuracy aligns with a successful model, achieving a high level of precision at 100%. Therefore, the Random forest classifier model can effectively forecast cricket match outcomes, providing valuable insights into which team is expected to emerge victorious.
